# %% [markdown]
# pip install bs4

# %% [markdown]
# pip install requests

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url="https://www.imdb.com/best-of/col-needham-2021-movies-rated-9-and-up/ls571474879/"

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(response.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <style>
#                 body#styleguide-v2 {
#                     background: no-repeat fixed center top #000;
#                 }
#             </style>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>Best of 2022 - Movies from 2021 which I Rated 9+ on IMDb - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
# ...

# %%
 name=soup.select(".lister-item-header a")

# %%
name
# Out:
# [<a href="/title/tt12789558/">Belfast</a>,
#  <a href="/title/tt3480822/">Black Widow</a>,
#  <a href="/title/tt11127680/">Boiling Point</a>,
#  <a href="/title/tt10366460/">CODA</a>,
#  <a href="/title/tt1160419/">Dune: Part One</a>,
#  <a href="/title/tt12800524/">Encounter</a>,
#  <a href="/title/tt9032400/">Eternals</a>,
#  <a href="/title/tt4513678/">Ghostbusters: Afterlife</a>,
#  <a href="/title/tt12680684/">È stata la mano di Dio</a>,
#  <a href="/title/tt9620288/">King Richard</a>,
#  <a href="/title/tt1893273/">The Last Letter from Your Lover</a>,
#  <a href="/title/tt9639470/">Last Night in Soho</a>,
#  <a href="/title/tt10016180/">The Little Things</a>,
#  <a href="/title/tt12229370/">Mothering Sunday</a>,
#  <a href="/title/tt7979580/">The Mitchells vs the Machines</a>,
#  <a href="/title/tt2382320/">No Time to Die</a>,
#  <a href="/title/tt12731980/">Old Henry</a>,
#  <a href="/title/tt12708658/">Les Olympiades, Paris 13e</a>,
# ...

# %%
import pandas as pd

# %%
ratings =soup.select(".ratings-imdb-rating")

# %%
ratings
# Out:
# [<div class="inline-block ratings-imdb-rating" data-value="7.3" name="ir"> <span class="global-sprite rating-star imdb-rating"></span> <strong>7.3</strong> </div>,
#  <div class="inline-block ratings-imdb-rating" data-value="6.7" name="ir"> <span class="global-sprite rating-star imdb-rating"></span> <strong>6.7</strong> </div>,
#  <div class="inline-block ratings-imdb-rating" data-value="7.5" name="ir"> <span class="global-sprite rating-star imdb-rating"></span> <strong>7.5</strong> </div>,
#  <div class="inline-block ratings-imdb-rating" data-value="8" name="ir"> <span class="global-sprite rating-star imdb-rating"></span> <strong>8.0</strong> </div>,
#  <div class="inline-block ratings-imdb-rating" data-value="8" name="ir"> <span class="global-sprite rating-star imdb-rating"></span> <strong>8.0</strong> </div>,
#  <div class="inline-block ratings-imdb-rating" data-value="5.9" name="ir"> <span class="global-sprite rating-star imdb-rating"></span> <strong>5.9</strong> </div>,
# ...

# %%
movielist =pd.DataFrame(name,columns=["list"])

# %%
movielist
# Out:
#                                list
# 0                           Belfast
# 1                       Black Widow
# 2                     Boiling Point
# 3                              CODA
# 4                    Dune: Part One
# 5                         Encounter
# 6                          Eternals
# 7           Ghostbusters: Afterlife
# 8            È stata la mano di Dio
# 9                      King Richard
# 10  The Last Letter from Your Lover
# 11               Last Night in Soho
# 12                The Little Things
# 13                 Mothering Sunday
# 14    The Mitchells vs the Machines
# 15                   No Time to Die
# 16                        Old Henry
# 17        Les Olympiades, Paris 13e
# 18                          Passing
# 19                     Petite maman
# 20                       Red Notice
# 21                   The Road Dance
# 22                       Sweetheart
# 23                          Spencer
# 24                  Nightmare Alley
# ...

# %%
movielist.to_csv('D://vickysan//movies')
