# %%
import pandas as pd

# %%
Salary=pd.DataFrame({'salary':[1000,50000,15000,2000],'cat':['little low','low','medium','high']})

# %%
Salary
# Out:
#    salary         cat
# 0    1000  little low
# 1   50000         low
# 2   15000      medium
# 3    2000        high

# %%
Salary.cat
# Out:
# 0    little low
# 1           low
# 2        medium
# 3          high
# Name: cat, dtype: object

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as pt

# %%
# %matplotlib inline

# %%
GA=pd.read_csv("D:/vickysan/Admission_Predict_Ver1.1 (1) (1).csv")

# %%
GA
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 4             5        314          103                  2  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 495         496        332          108                  5  4.5  4.0  9.02
# 496         497        337          117                  5  5.0  5.0  9.87
# 497         498        330          120                  5  4.5  5.0  9.56
# 498         499        312          103                  4  4.0  5.0  8.43
# 499         500        327          113                  4  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 0           1              0.92
# ...

# %%
san=GA.drop(['Serial No.','TOEFL Score','University Rating','SOP','LOR','CGPA','Research'],axis=1)

# %%
san
# Out:
#      GRE Score  Chance of Admit
# 0          337              0.92
# 1          324              0.76
# 2          316              0.72
# 3          322              0.80
# 4          314              0.65
# ..         ...               ...
# 495        332              0.87
# 496        337              0.96
# 497        330              0.93
# 498        312              0.73
# 499        327              0.84
#
# [500 rows x 2 columns]

# %%
GA.shape
# Out:
# (500, 9)

# %%
GA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
vky=GA.drop(['Serial No.','TOEFL Score','University Rating','SOP','LOR','Research'],axis=1)

# %%
vky
# Out:
#      GRE Score  CGPA  Chance of Admit
# 0          337  9.65              0.92
# 1          324  8.87              0.76
# 2          316  8.00              0.72
# 3          322  8.67              0.80
# 4          314  8.21              0.65
# ..         ...   ...               ...
# 495        332  9.02              0.87
# 496        337  9.87              0.96
# 497        330  9.56              0.93
# 498        312  8.43              0.73
# 499        327  9.04              0.84
#
# [500 rows x 3 columns]

# %%
x=vky.iloc[:,0].values.reshape(-1,1)
y=vky.iloc[:,-1].values.reshape(-1,1)

# %%
y
# Out:
# array([[0.92],
#        [0.76],
#        [0.72],
#        [0.8 ],
#        [0.65],
#        [0.9 ],
#        [0.75],
#        [0.68],
#        [0.5 ],
#        [0.45],
#        [0.52],
#        [0.84],
#        [0.78],
#        [0.62],
#        [0.61],
#        [0.54],
#        [0.66],
#        [0.65],
#        [0.63],
#        [0.62],
#        [0.64],
#        [0.7 ],
#        [0.94],
#        [0.95],
#        [0.97],
#        [0.94],
#        [0.76],
#        [0.44],
#        [0.46],
#        [0.54],
#        [0.65],
#        [0.74],
#        [0.91],
#        [0.9 ],
#        [0.94],
#        [0.88],
#        [0.64],
#        [0.58],
#        [0.52],
#        [0.48],
#        [0.46],
#        [0.49],
#        [0.53],
#        [0.87],
#        [0.91],
#        [0.88],
#        [0.86],
#        [0.89],
#        [0.82],
#        [0.78],
#        [0.76],
#        [0.56],
#        [0.78],
#        [0.72],
#        [0.7 ],
#        [0.64],
#        [0.64],
#        [0.46],
# ...

# %%
pt.scatter(x,y)
pt.xlabel('GRE SCORE')
pt.ylabel('CHA')
pt.title('linear reg')
pt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,train_size=0.5,random_state=0)

# %%
X_test.shape
# Out:
# (250, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_predict=lm.predict(X_test)

# %%
y_predict
# Out:
# array([[0.74266191],
#        [0.77455946],
#        [0.77455946],
#        [0.84898706],
#        [0.56190917],
#        [0.70013186],
#        [0.53001162],
#        [0.57254168],
#        [0.51937911],
#        [0.806457  ],
#        [0.7320294 ],
#        [0.76392694],
#        [0.70013186],
#        [0.68949934],
#        [0.91278215],
#        [0.51937911],
#        [0.79582449],
#        [0.7320294 ],
#        [0.82772203],
#        [0.55127665],
#        [0.49811408],
#        [0.76392694],
#        [0.50874659],
#        [0.8808846 ],
#        [0.78519197],
#        [0.74266191],
#        [0.81708952],
#        [0.66823431],
#        [0.61507174],
#        [0.59380671],
#        [0.72139688],
#        [0.50874659],
#        [0.56190917],
#        [0.79582449],
#        [0.71076437],
#        [0.53001162],
#        [0.84898706],
#        [0.806457  ],
#        [0.55127665],
#        [0.6576018 ],
#        [0.70013186],
#        [0.85961957],
#        [0.87025209],
# ...
